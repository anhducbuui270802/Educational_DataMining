# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# Đọc dữ liệu
df_diem = pd.read_csv("../data_clean/sinhvien_dtb_hocky.csv")
df_diem.head()
# Out:
#                                        mssv  hocky  namhoc  dtbhk  sotchk  \
# 0  48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      1    2016   6.45      13
# 1  48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      2    2016   5.86      17
# 2  48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      1    2017   6.54      16
# 3  48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      2    2017   5.67      23
# 4  48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      1    2018   2.27      21
#
#    hocky_sx
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %%
# Đọc dữ liệu
df_drl = pd.read_csv("../data_clean/07.diemrl.csv")
df_drl.drop(columns=['id'], inplace=True)
df_drl.head()
# Out:
#                                        mssv  hocky  namhoc  drl  xl_drl
# 0  2A10C466XPvAibaEXe8vcQUX+A6FeNIl5Loug1zV      2    2013   81       4
# 1  903ADF1AXPvAibaEXe9p5G9u2qRxxZEjiJjD4Ztl      2    2013   88       4
# 2  F06EDFFEXPvAibaEXe8KSegZW1rFPMNPBQ+c9rst      2    2013   94       5
# 3  AA868AD5XPvAibaEXe+1Gm1QkI5oNyTYwjwmgxhx      2    2013   86       4
# 4  E7105148XPvAibaEXe+E7LJdSZ9AW2sUcg4OSCnU      2    2013   88       4

# %%
df_drl.shape
# Out:
# (111978, 5)

# %%
df_diem.shape
# Out:
# (84952, 6)

# %%
merged_df = pd.merge(df_diem, df_drl, on=['mssv', 'hocky', 'namhoc'], how='left')

# %%
merged_df
# Out:
#                                            mssv  hocky  namhoc  dtbhk  sotchk  \
# 0      48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      1    2016   6.45      13
# 1      48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      2    2016   5.86      17
# 2      48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      1    2017   6.54      16
# 3      48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      2    2017   5.67      23
# 4      48685401XPvAibaEXe99yNsueYx+scOnjQSx4nXO      1    2018   2.27      21
# ...                                         ...    ...     ...    ...     ...
# 84947  EA2A92C2XPvAibaEXe99J3nD1pBZIshWCsT6VhsJ      1    2022   6.70       3
# 84948  ED5A0E45XPvAibaEXe/CiPILllTJf8s+lllUG7Kd      1    2022   7.80       3
# 84949  09DE3A51XPvAibaEXe/GEP39G15BdRSEDU3D3+LV      2    2022   0.00       0
# 84950  CCF627D0XPvAibaEXe+oAybUv81bbkc8L/mx+IhC      2    2022   0.00       0
# 84951  A6169055XPvAibaEXe81r7KrCH0uc4QKxDeoWYb4      2    2022   0.00       0
#
#        hocky_sx   drl  xl_drl
# ...

# %%
merged_df.isna().sum()
# Out:
# mssv           0
# hocky          0
# namhoc         0
# dtbhk          0
# sotchk         0
# hocky_sx       0
# drl         6913
# xl_drl      6913
# dtype: int64

# %% [markdown]
# * Thêm những giá trị drl còn thiếu bằng giá trị trung bình

# %%
merged_df['drl'] = merged_df['drl'].fillna(merged_df['drl'].mean().astype(int))

# %%
merged_df['xl_drl'] = merged_df['xl_drl'].fillna(4)

# %%
merged_df.isna().sum()
# Out:
# mssv        0
# hocky       0
# namhoc      0
# dtbhk       0
# sotchk      0
# hocky_sx    0
# drl         0
# xl_drl      0
# dtype: int64

# %%
merged_df.to_csv('../data_clean/dtb_drl.csv', index=False)
